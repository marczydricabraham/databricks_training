# %%
dbutils.widgets.text("catalog_name", "capstone_101", "Catalog Name")
catalog_name = dbutils.widgets.get("catalog_name")

spark.sql(f"CREATE CATALOG IF NOT EXISTS {catalog_name}")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {catalog_name}.bronze")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {catalog_name}.silver")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {catalog_name}.gold")

print(f"Catalog created: {catalog_name}")
print(f"Schemas created: {catalog_name}.bronze, {catalog_name}.silver, {catalog_name}.gold")

# %%
# Create Widgets for dynamic input
dbutils.widgets.text("catalog_name", "training_catalog", "Catalog Name")
dbutils.widgets.text("source_path", "/databricks-datasets/online_retail/data-001/", "Source CSV Path")

# Retrieve values
catalog = dbutils.widgets.get("catalog_name")
source_path = dbutils.widgets.get("source_path")
checkpoint_path = f"abfss://.../{catalog}/_checkpoints/bronze_ingestion" # Path for tracking incremental progress
